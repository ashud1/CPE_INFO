# %%
import pandas as pd

# %%
df=pd.ExcelFile(r"C:\Users\ashutosh_dwivedi02\Desktop\INFA\CPE_SWAP\SCM_Tech_Swaps.xlsx")

# %%
df

# %%
df.sheet_names
# Out:
# ['CZ', 'CH', 'DE', 'HU', 'IE', 'NL', 'PL', 'RO', 'SK', 'VM', 'Telenet']

# %%
df2=pd.read_excel(r"C:\Users\ashutosh_dwivedi02\Desktop\INFA\CPE_SWAP\SCM_Tech_Swaps.xlsx",sheet_name='DE')

# %%
df2={sheet_name:df.parse(sheet_name) for sheet_name in df.sheet_names}

# %% [markdown]
# df2['CZ'].iloc[8:]
# df2['CH'].iloc[10:]
# df2['DE'].iloc[6:]
# df2['HU'].iloc[7:]
# df2['IE'].iloc[7:]
# df2['PL'].iloc[8:]
# df2['RO'].iloc[8:]
# df2['SK'].iloc[8:]
# df2['VM'].iloc[8:]
# df2['Telenet'].iloc[2:]

# %%
df_CZ_CH
# Out:
#                                                                                                                                                                                                                                                                                                                                                                          Last  \
# NaN             NaN NaN             NaN NaN           NaN NaN                    NaN NaN                 2018                  2018                   2018                  2018                   2018                   2018                   2018                   2018                  2018                  2018                  2019                           2019
# ...

# %%
df_CZ_CH=pd.concat([df2['CZ'].iloc[8:],df2['CH'].iloc[10:]])

# %% [markdown]
# df2['CZ'].iloc[8:]
# df2['CH'].iloc[10:]
# df2['DE'].iloc[6:]
# df2['HU'].iloc[7:]
# df2['IE'].iloc[7:]
# df2['PL'].iloc[8:]
# df2['RO'].iloc[8:]
# df2['SK'].iloc[8:]
# df2['VM'].iloc[8:]
# df2['Telenet'].iloc[2:]

# %%
df_CZ_CH=pd.concat([df2['CZ'].iloc[8:],df2['CH'].iloc[10:],df2['DE'].iloc[6:] df2['HU'].iloa[7:] df2['IE'].iloc[7:] df2['PL'].iloc[8:] df2['RO'].iloc[8:] df2['SK'].iloc[8:] df2['VM'].iloc[8:] df2['Telenet'].iloc[2:]])

# %%
df_CZ_CH_DE=pd.concat([df2['CZ'].iloc[8:],df2['CH'].iloc[10:],df2['DE'].iloc[6:]])

# %%
df_CZ_CH_DE_HU=pd.concat([df_CZ_CH_DE,df2['HU'].iloc[7:],df2['IE'].iloc[7:],])

# %%
df2['HU'].iloc[7:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-39fbff64806f> in <module>()
# ----> 1 df2['HU'].iloa[7:]
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iloa'

# %%
df2['CZ'].iloc[8:]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                          Last  \
# NaN             NaN NaN             NaN NaN           NaN NaN                    NaN NaN                2018                   2018                   2018                   2018                   2018                  2018                   2018                   2018                  2018                  2018                  2019                           2019
# ...

# %%
df_COMBINED=pd.concat([df2['CZ'].iloc[8:],df2['CH'].iloc[10:],df2['DE'].iloc[6:],df2['HU'].iloc[7:],df2['IE'].iloc[7:],df2['PL'].iloc[8:],df2['RO'].iloc[8:]])

# %%
df_COMBINED
# Out:
#                                                                                                                                                                                                                                                                                                                                                                        Last  \
# NaN             NaN NaN             NaN NaN           NaN NaN                    NaN NaN                 2018                  2018                   2018                  2018                  2018                  2018                   2018                   2018                  2018                  2018                  2019                           2019
# ...

# %%
df2['RO'].iloc[:]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                             Last  \
# NaN                  NaN NaN                  NaN NaN           NaN                                        NaN                    NaN Month               11                     12                     01                     02                    03                     04                    05                    06                     07                     08                     09                               10
# ...

# %%
df_ro=df2['RO'].iloc[4:]

# %%
df_ro_fill=df_ro.fillna(method='ffill')

# %%
df_ro_fill
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                             Last  \
# NaN                  NaN NaN                  NaN NaN           NaN                                        NaN                    NaN Month               11                     12                     01                     02                    03                     04                    05                    06                     07                     08                     09                               10
# ...

# %%
df_ro.columns
# Out:
# Index(['Last', 'Unnamed: 1', 'Total', 'Unnamed: 3'], dtype='object')

# %%
df.columns.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-d14e0772c22c> in <module>()
# ----> 1 df.columns.len
#
# AttributeError: 'ExcelFile' object has no attribute 'columns'

# %%
len(df_ro.columns)
# Out:
# 4

# %%
df_ro.columns
# Out:
# Index(['Last', 'Unnamed: 1', 'Total', 'Unnamed: 3'], dtype='object')

# %%
df_ro=df2['RO'].iloc[15:]

# %%
df_ro
# Out:
#                                                                                                                                                                                                                                                                 Last  \
# CI+                  C   CI+C                 NaN NaN NaN NaN                    NaN Commercial          5.560000e+02 3.660000e+02 5.070000e+02 4.100000e+02 5.220000e+02 5.080000e+02 2.930000e+02 6.490000e+02 6.670000e+02 5.570000e+02 6.290000e+02          562
# NaN                  NaN NaN                  NaN NaN NaN NaN                    NaN Commercial %        1.887644e-03 1.224240e-03 1.668900e-03 1.045028e-03 1.667194e-03 1.597067e-03 9.071825e-04 1.968719e-03 1.973630e-03 1.605025e-03 1.777720e-03    0.0015599
# ...

# %%
df_ro=df2['RO'].iloc[10:]

# %%
df_ro
# Out:
#                                                                                                                                                                                                                                                                           Last  \
# NaN                  NaN NaN                  NaN NaN           NaN NaN                    NaN NaN                 NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN                   NaN
# CI+                  T   CI+T                 NaN Entertainment NaN SmarDTV\nCI+           NaN Technical           6.950000e+02 5.580000e+02 6.440000e+02 6.790000e+02 9.030000e+02 8.800000e+02 5.400000e+02 8.880000e+02 8.660000e+02 8.420000e+02 8.490000e+02          890
# ...

# %%
df_ro=df2['RO'].iloc[10:,5:]

# %%
df_ro
# Out:
# Empty DataFrame
# Columns: []
# Index: [(nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan), (CI+, T, CI+T, nan, Entertainment, nan, SmarDTV
# ...

# %%
df_ro.columns
# Out:
# Index([], dtype='object')

# %%
data=[]

# %%
data.insert(0,{"C1":"C1","C2":"C2"})

# %%
type(data)
# Out:
# list

# %%
data=pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new=pd.concat([data,df_ro])

# %%
df_new.columns
# Out:
# Index(['C1', 'C2'], dtype='object')

# %%
df_new
# Out:
#                                                      C1   C2
# 0                                                    C1   C2
# (CI+, T, CI+T, nan, Entertainment, nan, SmarDTV...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Techni...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Proact...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Proact...  NaN  NaN
# (CI+, C, CI+C, nan, nan, nan, nan, nan, Commerc...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Commer...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Total,...  NaN  NaN
# (CI+ CAM, nan, CI+ CAM, nan, nan, nan, nan, nan...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, % vs. ...  NaN  NaN
# (DCI52, T, DCI52T, nan, nan, nan, Thomson\nDCI5...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Techni...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Proact...  NaN  NaN
# (nan, nan, nan, nan, nan, nan, nan, nan, Proact...  NaN  NaN
# ...

# %%
df_new.columns
# Out:
# Index(['C1', 'C2'], dtype='object')

# %%
df_ro
# Out:
# Empty DataFrame
# Columns: []
# Index: [(CI+, T, CI+T, nan, Entertainment, nan, SmarDTV
# ...

# %%
df_ro_2=df_ro.drop(labels=None,axis=0)

# %%
df_ro_2
# Out:
# Empty DataFrame
# Columns: []
# Index: [(CI+, T, CI+T, nan, Entertainment, nan, SmarDTV
# ...

# %%
df_ro_2.columns
# Out:
# Index([], dtype='object')

# %%
df_ro=df2['RO'].iloc[11:,5:]

# %%
df_ro
# Out:
# Empty DataFrame
# Columns: []
# Index: [(CI+, T, CI+T, nan, Entertainment, nan, SmarDTV
# ...

# %%
df_ro.columns
# Out:
# Index([], dtype='object')

# %%
Index(df_ro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-52f29bc1daac> in <module>()
# ----> 1 Index(df_ro)
#
# NameError: name 'Index' is not defined
